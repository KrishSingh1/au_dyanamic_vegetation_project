# %% [markdown]
# # Cliping A tiff File

# %%
import rasterio
import rasterio.mask
import fiona
import matplotlib.pyplot as plt
import numpy as np
import os 
import pandas as pd

# %%
with fiona.open("../DATASETS/Soils_and_Landscape_Grid_of_Australia/AusPlots_Polygons.shp", "r") as shapefile:
    shapes = [feature["geometry"] for feature in shapefile]
    shapes_name = [properties["properties"]['Name'] for properties in shapefile]

# %%
data_file_path = '../DATASETS/Soils_and_Landscape_Grid_of_Australia/DownloadedGrids/'
slga_datafiles = os.listdir(data_file_path) # list all datafiles 
slga_datafiles
# Out:
# ['CLY_000_005_EV_N_P_AU_TRN_N_20210902.tif',
#  'CLY_005_015_EV_N_P_AU_TRN_N_20210902.tif',
#  'CLY_015_030_EV_N_P_AU_TRN_N_20210902.tif',
#  'CLY_030_060_EV_N_P_AU_TRN_N_20210902.tif',
#  'CLY_060_100_EV_N_P_AU_TRN_N_20210902.tif',
#  'CLY_100_200_EV_N_P_AU_TRN_N_20210902.tif',
#  'SLT_030_060_EV_N_P_AU_TRN_N_20210902.tif']

# %%
column_names = [] # create user_friendly column names 
for i in slga_datafiles:
    split_words = i.split('_')[:3]
    column_names.append('_'.join(split_words))
column_names
# Out:
# ['CLY_000_005',
#  'CLY_005_015',
#  'CLY_015_030',
#  'CLY_030_060',
#  'CLY_060_100',
#  'CLY_100_200',
#  'SLT_030_060']

# %%
site_slga_data = pd.DataFrame(columns = column_names, index = shapes_name)
site_slga_data.head()
# Out:
#            CLY_000_005 CLY_005_015 CLY_015_030 CLY_030_060 CLY_060_100  \
# NSABBS0001         NaN         NaN         NaN         NaN         NaN
# NSABBS0002         NaN         NaN         NaN         NaN         NaN
# NSABBS0003         NaN         NaN         NaN         NaN         NaN
# NSABBS0004         NaN         NaN         NaN         NaN         NaN
# NSABBS0005         NaN         NaN         NaN         NaN         NaN
#
#            CLY_100_200 SLT_030_060
# NSABBS0001         NaN         NaN
# NSABBS0002         NaN         NaN
# NSABBS0003         NaN         NaN
# NSABBS0004         NaN         NaN
# NSABBS0005         NaN         NaN

# %% [markdown]
# ```python
#
#
# for col_idx, df in enumerate(slga_datafiles):
#
#     variable_mean = []
#     file_path = data_file_path+df
#
#     with rasterio.open(file_path) as src:
#
#         for i, shape in enumerate(shapes):
#             shape = [shape] # shape has to be in a list
#             shape_name = shapes_name[i] # reference the name of  the site
#
#             out_image, out_transform = rasterio.mask.mask(src, shape, crop=True) # perform masking
#
#             # out_meta = src.meta # update meta data of masked content
#
#             # out_meta.update({"driver": "GTiff",
#             #              "height": out_image.shape[1],
#             #              "width": out_image.shape[2],
#             #              "transform": out_transform})
#
#             image_mean = np.nanmean(out_image)
#             variable_mean.append(image_mean)
#
#     site_slga_data[column_names[col_idx]] = variable_mean
#
#         #with rasterio.open(f"../DATASETS/Soils_and_Landscape_Grid_of_Australia/Output/{file_name}/{shape_name}_{file_name}.tif" , "w", **out_meta) as dest:
#         #    dest.write(out_image)
# ```

# %%
for col_idx, df in enumerate(slga_datafiles):
    
    variable_mean = []
    file_path = data_file_path+df

    with rasterio.open(file_path) as src:
        
        for i, shape in enumerate(shapes):
            
            shape = [shape] # shape has to be in a list 
            shape_name = shapes_name[i] # reference the name of  the site 
            out_image, out_transform = rasterio.mask.mask(src, shape, crop=True) # perform masking 
            image_mean = np.nanmean(out_image)
            variable_mean.append(image_mean)
        
    site_slga_data[column_names[col_idx]] = variable_mean
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)
# C:\Users\krish\AppData\Local\Temp\ipykernel_30156\4211678436.py:21: RuntimeWarning: Mean of empty slice
#   image_mean = np.nanmean(out_image)

# %%
site_slga_data
# Out:
#             CLY_000_005  CLY_005_015  CLY_015_030  CLY_030_060  CLY_060_100  \
# NSABBS0001         16.5         17.5         20.5         23.5         24.0
# NSABBS0002         15.5         16.5         21.5         26.5         25.0
# NSABBS0003         11.0         13.0         16.0         20.0         25.0
# NSABBS0004          9.0         12.0         14.0         16.0         21.0
# NSABBS0005         10.0         13.0         15.0         14.0         21.0
# ...                 ...          ...          ...          ...          ...
# WAFWAR0008          8.0          8.5         12.0         18.0         26.5
# WAFWAR0009          8.0          8.5         11.5         13.0         22.0
# WAGCOO0001         11.0         12.0         15.0         18.0         18.0
# WAGCOO0002          8.0          8.0          9.0         11.0         12.0
# WAGCOO0004         13.0         14.0         19.0         21.0         21.0
#
#             CLY_100_200  SLT_030_060
# NSABBS0001         29.0         13.0
# NSABBS0002         35.5         11.5
# NSABBS0003         27.0          8.0
# NSABBS0004         23.0          8.0
# NSABBS0005         24.0          8.0
# ...                 ...          ...
# WAFWAR0008         23.5          9.0
# WAFWAR0009         13.0          7.0
# WAGCOO0001         22.0          7.0
# WAGCOO0002         18.0          4.0
# WAGCOO0004         24.0         10.0
#
# [897 rows x 7 columns]
