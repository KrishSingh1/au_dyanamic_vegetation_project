# %% [markdown]
# # AusPlots Soil Dataset Validation

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from scipy import stats

# %%
site_slga_data = pd.read_csv('../DATASETS/Soils_and_Landscape_Grid_of_Australia/Output/site_slga_data.csv', index_col = 0).copy()
site_slga_data.head()
# Out:
#             CLY_000_005  CLY_005_015  CLY_015_030  CLY_030_060  CLY_060_100  \
# NSABHC0015         17.0    19.000000    23.000000         25.0    27.000000
# NSABHC0018         14.0    17.000000    19.000000         23.0    27.000000
# NSABHC0019         16.0    18.000000    20.000000         23.0    28.000000
# NSABHC0020         15.0    17.000000    22.500000         24.5    27.000000
# NSABHC0021         18.0    21.666666    27.333334         30.0    29.333334
#
#             CLY_100_200  SLT_030_060
# NSABHC0015    38.000000    15.000000
# NSABHC0018    28.000000    14.000000
# NSABHC0019    28.000000    14.000000
# NSABHC0020    31.000000    13.000000
# NSABHC0021    38.666668    15.333333

# %%
soils_char = pd.read_csv('../DATASETS/AusPlots_Extracted_Data/extracted_soil_char_2-0-6.csv', index_col = 0).copy()
soils_char.head()
# Out:
#   soil.char.site_unique soil.char.site_location_name  \
# 1      NSABHC0013-53608                   NSABHC0013
# 2      WAAPIL0030-58057                   WAAPIL0030
# 3      WAAPIL0030-58057                   WAAPIL0030
# 4      WAAPIL0030-58057                   WAAPIL0030
# 5      NSABHC0013-53608                   NSABHC0013
#
#    soil.char.site_location_visit_id  soil.char.upper_depth  \
# 1                             53608                   0.50
# 2                             58057                   0.00
# 3                             58057                   0.09
# 4                             58057                   0.45
# 5                             53608                   0.30
#
#    soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 1                   0.60                NC                      NC
# 2                   0.09                A1                      MC
# 3                   0.45              B21K                     MHC
# 4                   0.60              B22K                      MC
# 5                   0.40                NC                      NC
#
#   soil.char.texture_qualifier soil.char.texture_modifier  \
# 1                         NaN                        NaN
# 2                          NC                         NC
# 3                          NC                         NC
# 4                          NC                         NC
# 5                         NaN                        NaN
#
#   soil.char.colour_when_moist  ... soil.char.ph soil.char.pedality_grade  \
# 1                         NaN  ...          NaN                       NC
# 2                   2.5YR2.54  ...          6.8                        M
# 3                     2.5YR34  ...          7.9                        M
# 4                       10R34  ...          8.6                       NC
# 5                         NaN  ...          NaN                       NC
#
#   soil.char.pedality_fabric soil.char.next_size_type_2  \
# 1                        NC                         NC
# 2                         R                         NC
# 3                         R                         NC
# 4                        NC                         NC
# 5                        NC                         NC
#
#   soil.char.next_size_type_1 soil.char.smallest_size_type_2  \
# 1                         NC                             NC
# 2                         NC                             NC
# 3                         NC                             NC
# 4                         NC                             NC
# 5                         NC                             NC
#
#   soil.char.smallest_size_type_1 soil.char.next_size_2 soil.char.next_size_1  \
# 1                             NC                   NaN                  11.0
# 2                             AB                   NaN                   NaN
# 3                             AB                   NaN                   NaN
# 4                             NC                   NaN                   NaN
# 5                             NC                   NaN                  11.0
#
#    soil.char.layer_barcode
# 1               NSA 050414
# 2                WAA053908
# 3                WAA053909
# 4                WAA053910
# 5               NSA 050412
#
# [5 rows x 34 columns]

# %%
classifications = {
    'S': [0, 5],
    'LS': [5, 5],
    'CS': [5, 10],
    'SL': [10, 20],
    'L' : [25, 25],
    'ZL': [25, 25],
    'SCL' : [20, 30],
    'CL': [30, 35],
    'CLS' : [30, 35],
    'ZCL' : [30, 35],
    'LC' : [35, 40],
    'LMC' : [40, 45],
    'MC': [45, 55],
    'MHC': [50, 100],
    'HC': [50, 100],
    'NC': [-1, -1]
}
classifications = pd.DataFrame(classifications)

# %%
soils_char
# Out:
#      soil.char.site_unique soil.char.site_location_name  \
# 1         NSABHC0013-53608                   NSABHC0013
# 2         WAAPIL0030-58057                   WAAPIL0030
# 3         WAAPIL0030-58057                   WAAPIL0030
# 4         WAAPIL0030-58057                   WAAPIL0030
# 5         NSABHC0013-53608                   NSABHC0013
# ...                    ...                          ...
# 3721      QDADEU0002-58962                   QDADEU0002
# 3722      QDADEU0002-58962                   QDADEU0002
# 3723      QDADEU0002-58962                   QDADEU0002
# 3724      QDADEU0002-58962                   QDADEU0002
# 3725      QDADEU0002-58962                   QDADEU0002
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 1                                53608                   0.50
# 2                                58057                   0.00
# 3                                58057                   0.09
# 4                                58057                   0.45
# 5                                53608                   0.30
# ...                                ...                    ...
# 3721                             58962                   0.40
# 3722                             58962                   0.50
# 3723                             58962                   0.60
# 3724                             58962                   0.70
# 3725                             58962                   0.85
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 1                      0.60                NC                      NC
# 2                      0.09                A1                      MC
# 3                      0.45              B21K                     MHC
# 4                      0.60              B22K                      MC
# 5                      0.40                NC                      NC
# ...                     ...               ...                     ...
# 3721                   0.50                B1                     SCL
# 3722                   0.60                B1                     SCL
# 3723                   0.70                B1                     SCL
# 3724                   0.85               B21                      LC
# 3725                   1.00               B22                      LC
#
#      soil.char.texture_qualifier soil.char.texture_modifier  \
# 1                            NaN                        NaN
# 2                             NC                         NC
# 3                             NC                         NC
# 4                             NC                         NC
# 5                            NaN                        NaN
# ...                          ...                        ...
# 3721                          NC                          K
# 3722                          NC                          K
# 3723                          NC                          K
# 3724                          NC                          K
# 3725                          NC                          K
#
#      soil.char.colour_when_moist  ... soil.char.ph soil.char.pedality_grade  \
# 1                            NaN  ...          NaN                       NC
# 2                      2.5YR2.54  ...          6.8                        M
# 3                        2.5YR34  ...          7.9                        M
# 4                          10R34  ...          8.6                       NC
# 5                            NaN  ...          NaN                       NC
# ...                          ...  ...          ...                      ...
# 3721                     2.5YR48  ...          NaN                        W
# 3722                     2.5YR48  ...          7.3                        W
# 3723                     2.5YR48  ...          NaN                        W
# 3724                     2.5YR58  ...          7.2                        W
# 3725                       5YR68  ...          7.8                        W
#
#      soil.char.pedality_fabric soil.char.next_size_type_2  \
# 1                           NC                         NC
# 2                            R                         NC
# 3                            R                         NC
# 4                           NC                         NC
# 5                           NC                         NC
# ...                        ...                        ...
# 3721                        NC                         NC
# 3722                        NC                         NC
# 3723                        NC                         NC
# 3724                        NC                         NC
# 3725                        NC                         NC
#
#      soil.char.next_size_type_1 soil.char.smallest_size_type_2  \
# 1                            NC                             NC
# 2                            NC                             NC
# 3                            NC                             NC
# 4                            NC                             NC
# 5                            NC                             NC
# ...                         ...                            ...
# 3721                         NC                             NC
# 3722                         NC                             NC
# 3723                         NC                             NC
# 3724                         NC                             NC
# 3725                         NC                             NC
#
#      soil.char.smallest_size_type_1 soil.char.next_size_2  \
# 1                                NC                   NaN
# 2                                AB                   NaN
# 3                                AB                   NaN
# 4                                NC                   NaN
# 5                                NC                   NaN
# ...                             ...                   ...
# 3721                             SB                   NaN
# 3722                             SB                   NaN
# 3723                             SB                   NaN
# 3724                             SB                   NaN
# 3725                             SB                   NaN
#
#      soil.char.next_size_1  soil.char.layer_barcode
# 1                     11.0               NSA 050414
# 2                      NaN                WAA053908
# 3                      NaN                WAA053909
# 4                      NaN                WAA053910
# 5                     11.0               NSA 050412
# ...                    ...                      ...
# 3721                   NaN                      NaN
# 3722                   NaN                QDA055986
# 3723                   NaN                      NaN
# 3724                   NaN                QDA055987
# 3725                   NaN                QDA055988
#
# [3725 rows x 34 columns]

# %%
soils_char.loc[soils_char['soil.char.texture_grade'].isna(), 'soil.char.texture_grade'] = 'NC'

# %%
cly_min = [] 
cly_max = [] 
for i,v in soils_char.iterrows():
    texture_grade = v['soil.char.texture_grade']
    min_range = np.min(classifications.loc[0, texture_grade])
    max_range = np.max(classifications.loc[1, texture_grade])
    cly_min.append(min_range)
    cly_max.append(max_range)

# %%
soils_char['cly_min'] = cly_min
soils_char['cly_max'] = cly_max

# %%
soils_char['clay_mid'] = (soils_char['cly_min'] + soils_char['cly_max'])/2

# %%
soils_char.head()
# Out:
#   soil.char.site_unique soil.char.site_location_name  \
# 1      NSABHC0013-53608                   NSABHC0013
# 2      WAAPIL0030-58057                   WAAPIL0030
# 3      WAAPIL0030-58057                   WAAPIL0030
# 4      WAAPIL0030-58057                   WAAPIL0030
# 5      NSABHC0013-53608                   NSABHC0013
#
#    soil.char.site_location_visit_id  soil.char.upper_depth  \
# 1                             53608                   0.50
# 2                             58057                   0.00
# 3                             58057                   0.09
# 4                             58057                   0.45
# 5                             53608                   0.30
#
#    soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 1                   0.60                NC                      NC
# 2                   0.09                A1                      MC
# 3                   0.45              B21K                     MHC
# 4                   0.60              B22K                      MC
# 5                   0.40                NC                      NC
#
#   soil.char.texture_qualifier soil.char.texture_modifier  \
# 1                         NaN                        NaN
# 2                          NC                         NC
# 3                          NC                         NC
# 4                          NC                         NC
# 5                         NaN                        NaN
#
#   soil.char.colour_when_moist  ... soil.char.next_size_type_2  \
# 1                         NaN  ...                         NC
# 2                   2.5YR2.54  ...                         NC
# 3                     2.5YR34  ...                         NC
# 4                       10R34  ...                         NC
# 5                         NaN  ...                         NC
#
#   soil.char.next_size_type_1 soil.char.smallest_size_type_2  \
# 1                         NC                             NC
# 2                         NC                             NC
# 3                         NC                             NC
# 4                         NC                             NC
# 5                         NC                             NC
#
#   soil.char.smallest_size_type_1 soil.char.next_size_2 soil.char.next_size_1  \
# 1                             NC                   NaN                  11.0
# 2                             AB                   NaN                   NaN
# 3                             AB                   NaN                   NaN
# 4                             NC                   NaN                   NaN
# 5                             NC                   NaN                  11.0
#
#   soil.char.layer_barcode cly_min cly_max  clay_mid
# 1              NSA 050414      -1      -1      -1.0
# 2               WAA053908      45      55      50.0
# 3               WAA053909      50     100      75.0
# 4               WAA053910      45      55      50.0
# 5              NSA 050412      -1      -1      -1.0
#
# [5 rows x 37 columns]

# %%
soils_char['depth_mid'] = (soils_char['soil.char.upper_depth'] + soils_char['soil.char.lower_depth'])/2

# %%
soils_char.head()
# Out:
#   soil.char.site_unique soil.char.site_location_name  \
# 1      NSABHC0013-53608                   NSABHC0013
# 2      WAAPIL0030-58057                   WAAPIL0030
# 3      WAAPIL0030-58057                   WAAPIL0030
# 4      WAAPIL0030-58057                   WAAPIL0030
# 5      NSABHC0013-53608                   NSABHC0013
#
#    soil.char.site_location_visit_id  soil.char.upper_depth  \
# 1                             53608                   0.50
# 2                             58057                   0.00
# 3                             58057                   0.09
# 4                             58057                   0.45
# 5                             53608                   0.30
#
#    soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 1                   0.60                NC                      NC
# 2                   0.09                A1                      MC
# 3                   0.45              B21K                     MHC
# 4                   0.60              B22K                      MC
# 5                   0.40                NC                      NC
#
#   soil.char.texture_qualifier soil.char.texture_modifier  \
# 1                         NaN                        NaN
# 2                          NC                         NC
# 3                          NC                         NC
# 4                          NC                         NC
# 5                         NaN                        NaN
#
#   soil.char.colour_when_moist  ... soil.char.next_size_type_1  \
# 1                         NaN  ...                         NC
# 2                   2.5YR2.54  ...                         NC
# 3                     2.5YR34  ...                         NC
# 4                       10R34  ...                         NC
# 5                         NaN  ...                         NC
#
#   soil.char.smallest_size_type_2 soil.char.smallest_size_type_1  \
# 1                             NC                             NC
# 2                             NC                             AB
# 3                             NC                             AB
# 4                             NC                             NC
# 5                             NC                             NC
#
#   soil.char.next_size_2 soil.char.next_size_1 soil.char.layer_barcode cly_min  \
# 1                   NaN                  11.0              NSA 050414      -1
# 2                   NaN                   NaN               WAA053908      45
# 3                   NaN                   NaN               WAA053909      50
# 4                   NaN                   NaN               WAA053910      45
# 5                   NaN                  11.0              NSA 050412      -1
#
#   cly_max clay_mid  depth_mid
# 1      -1     -1.0      0.550
# 2      55     50.0      0.045
# 3     100     75.0      0.270
# 4      55     50.0      0.525
# 5      -1     -1.0      0.350
#
# [5 rows x 38 columns]

# %%
depth_intervals = []

for i in soils_char['depth_mid']:
    if i > 0.00 and i < 0.05:
        depth_intervals.append('CLY_000_005')
    elif i >= 0.05 and i < 0.15:
        depth_intervals.append('CLY_005_015')
    elif i >= 0.15 and i < 0.30:
        depth_intervals.append('CLY_015_030')
    elif i >= 0.30 and i < 0.60:
        depth_intervals.append('CLY_030_060')
    elif i >= 0.60 and i < 1.00:
        depth_intervals.append('CLY_060_100')
    elif i >= 1.00 and i < 2.00:
        depth_intervals.append('CLY_100_200')
    else:
        depth_intervals.append(-1)

# %%
soils_char['depth_interval'] = depth_intervals
soils_char['depth_length'] = abs(soils_char['soil.char.upper_depth'] - soils_char['soil.char.lower_depth'])

# %%
soils_char
# Out:
#      soil.char.site_unique soil.char.site_location_name  \
# 1         NSABHC0013-53608                   NSABHC0013
# 2         WAAPIL0030-58057                   WAAPIL0030
# 3         WAAPIL0030-58057                   WAAPIL0030
# 4         WAAPIL0030-58057                   WAAPIL0030
# 5         NSABHC0013-53608                   NSABHC0013
# ...                    ...                          ...
# 3721      QDADEU0002-58962                   QDADEU0002
# 3722      QDADEU0002-58962                   QDADEU0002
# 3723      QDADEU0002-58962                   QDADEU0002
# 3724      QDADEU0002-58962                   QDADEU0002
# 3725      QDADEU0002-58962                   QDADEU0002
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 1                                53608                   0.50
# 2                                58057                   0.00
# 3                                58057                   0.09
# 4                                58057                   0.45
# 5                                53608                   0.30
# ...                                ...                    ...
# 3721                             58962                   0.40
# 3722                             58962                   0.50
# 3723                             58962                   0.60
# 3724                             58962                   0.70
# 3725                             58962                   0.85
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 1                      0.60                NC                      NC
# 2                      0.09                A1                      MC
# 3                      0.45              B21K                     MHC
# 4                      0.60              B22K                      MC
# 5                      0.40                NC                      NC
# ...                     ...               ...                     ...
# 3721                   0.50                B1                     SCL
# 3722                   0.60                B1                     SCL
# 3723                   0.70                B1                     SCL
# 3724                   0.85               B21                      LC
# 3725                   1.00               B22                      LC
#
#      soil.char.texture_qualifier soil.char.texture_modifier  \
# 1                            NaN                        NaN
# 2                             NC                         NC
# 3                             NC                         NC
# 4                             NC                         NC
# 5                            NaN                        NaN
# ...                          ...                        ...
# 3721                          NC                          K
# 3722                          NC                          K
# 3723                          NC                          K
# 3724                          NC                          K
# 3725                          NC                          K
#
#      soil.char.colour_when_moist  ... soil.char.smallest_size_type_1  \
# 1                            NaN  ...                             NC
# 2                      2.5YR2.54  ...                             AB
# 3                        2.5YR34  ...                             AB
# 4                          10R34  ...                             NC
# 5                            NaN  ...                             NC
# ...                          ...  ...                            ...
# 3721                     2.5YR48  ...                             SB
# 3722                     2.5YR48  ...                             SB
# 3723                     2.5YR48  ...                             SB
# 3724                     2.5YR58  ...                             SB
# 3725                       5YR68  ...                             SB
#
#      soil.char.next_size_2 soil.char.next_size_1 soil.char.layer_barcode  \
# 1                      NaN                  11.0              NSA 050414
# 2                      NaN                   NaN               WAA053908
# 3                      NaN                   NaN               WAA053909
# 4                      NaN                   NaN               WAA053910
# 5                      NaN                  11.0              NSA 050412
# ...                    ...                   ...                     ...
# 3721                   NaN                   NaN                     NaN
# 3722                   NaN                   NaN               QDA055986
# 3723                   NaN                   NaN                     NaN
# 3724                   NaN                   NaN               QDA055987
# 3725                   NaN                   NaN               QDA055988
#
#      cly_min cly_max clay_mid depth_mid depth_interval  depth_length
# 1         -1      -1     -1.0     0.550    CLY_030_060          0.10
# 2         45      55     50.0     0.045    CLY_000_005          0.09
# 3         50     100     75.0     0.270    CLY_015_030          0.36
# 4         45      55     50.0     0.525    CLY_030_060          0.15
# 5         -1      -1     -1.0     0.350    CLY_030_060          0.10
# ...      ...     ...      ...       ...            ...           ...
# 3721      20      30     25.0     0.450    CLY_030_060          0.10
# 3722      20      30     25.0     0.550    CLY_030_060          0.10
# 3723      20      30     25.0     0.650    CLY_060_100          0.10
# 3724      35      40     37.5     0.775    CLY_060_100          0.15
# 3725      35      40     37.5     0.925    CLY_060_100          0.15
#
# [3725 rows x 40 columns]

# %%
soils_char_essential = soils_char[['soil.char.site_location_name', 'soil.char.upper_depth','soil.char.lower_depth','depth_mid','clay_mid', 'depth_interval', 'depth_length', 'soil.char.texture_grade']]
soils_char_essential.head()
# Out:
#   soil.char.site_location_name  soil.char.upper_depth  soil.char.lower_depth  \
# 1                   NSABHC0013                   0.50                   0.60
# 2                   WAAPIL0030                   0.00                   0.09
# 3                   WAAPIL0030                   0.09                   0.45
# 4                   WAAPIL0030                   0.45                   0.60
# 5                   NSABHC0013                   0.30                   0.40
#
#    depth_mid  clay_mid depth_interval  depth_length soil.char.texture_grade
# 1      0.550      -1.0    CLY_030_060          0.10                      NC
# 2      0.045      50.0    CLY_000_005          0.09                      MC
# 3      0.270      75.0    CLY_015_030          0.36                     MHC
# 4      0.525      50.0    CLY_030_060          0.15                      MC
# 5      0.350      -1.0    CLY_030_060          0.10                      NC

# %%
soils_char_essential = soils_char_essential[ (soils_char_essential['clay_mid'] != -1.0) & (soils_char_essential['depth_interval'] != -1)]
soils_char_essential.head()
# Out:
#    soil.char.site_location_name  soil.char.upper_depth  soil.char.lower_depth  \
# 2                    WAAPIL0030                   0.00                   0.09
# 3                    WAAPIL0030                   0.09                   0.45
# 4                    WAAPIL0030                   0.45                   0.60
# 9                    WAAPIL0031                   0.00                   0.17
# 10                   WAAPIL0032                   0.08                   0.16
#
#     depth_mid  clay_mid depth_interval  depth_length soil.char.texture_grade
# 2       0.045      50.0    CLY_000_005          0.09                      MC
# 3       0.270      75.0    CLY_015_030          0.36                     MHC
# 4       0.525      50.0    CLY_030_060          0.15                      MC
# 9       0.085      15.0    CLY_005_015          0.17                      SL
# 10      0.120      25.0    CLY_005_015          0.08                     SCL

# %%
slga_clay = []
for i, v in soils_char_essential.iterrows():
    #print(v['depth_interval'])
    clay_value = site_slga_data.loc[site_slga_data.index == v['soil.char.site_location_name'], v['depth_interval']].values[0]
    slga_clay.append(clay_value)

# %%
soils_char_essential['slga_clay'] = slga_clay

# %%
soils_char_essential = soils_char_essential[soils_char_essential['slga_clay'].isna() == False]

# %%
soils_char_essential.head()
# Out:
#    soil.char.site_location_name  soil.char.upper_depth  soil.char.lower_depth  \
# 2                    WAAPIL0030                   0.00                   0.09
# 3                    WAAPIL0030                   0.09                   0.45
# 4                    WAAPIL0030                   0.45                   0.60
# 9                    WAAPIL0031                   0.00                   0.17
# 10                   WAAPIL0032                   0.08                   0.16
#
#     depth_mid  clay_mid depth_interval  depth_length soil.char.texture_grade  \
# 2       0.045      50.0    CLY_000_005          0.09                      MC
# 3       0.270      75.0    CLY_015_030          0.36                     MHC
# 4       0.525      50.0    CLY_030_060          0.15                      MC
# 9       0.085      15.0    CLY_005_015          0.17                      SL
# 10      0.120      25.0    CLY_005_015          0.08                     SCL
#
#     slga_clay
# 2        19.5
# 3        27.0
# 4        28.0
# 9        16.0
# 10       23.0

# %%
def plot_boxplot(grade_value, classifications, dataset):
    
    dataset = dataset[dataset['soil.char.texture_grade'] == grade_value]
    
    if len(dataset) > 0:
    
        dataset.boxplot(column = ['slga_clay'], by = ['depth_interval'], figsize = (10,5))
        plt.axhline(y = classifications[grade_value][0], color = 'red', linestyle = 'dashed')
        plt.axhline(y = (classifications[grade_value][0] + classifications[grade_value][1])/2, color = 'black', linestyle = 'dashed')
        plt.axhline(y = classifications[grade_value][1], color = 'red', linestyle = 'dashed')
        plt.suptitle(grade_value) 
        plt.ylim(0, 100)
        plt.show()

# %%
for i in classifications.keys():
    if i != 'NC':
        plot_boxplot(i, classifications, soils_char_essential)

# %%
soils_char_essential['error'] = np.abs(soils_char_essential['slga_clay'] - soils_char_essential['clay_mid'])

# %%
soils_char_essential['State'] = [i[:2] for i in soils_char_essential['soil.char.site_location_name'].values]

# %%
soils_char_essential[['State','error']].groupby('State').describe()
# Out:
#        error
#        count       mean        std  min    25%   50%    75%   max
# State
# NS     233.0   8.769313   6.255700  0.0  4.000  8.00  11.50  44.5
# NT     503.0   7.580020   5.629513  0.0  4.000  6.50  10.00  50.5
# QD     440.0  13.071591  10.973617  0.0  5.000  9.00  18.50  51.0
# SA     693.0  10.219096  10.027565  0.0  4.000  7.00  12.50  60.0
# TC     113.0  12.522124   9.905162  0.0  5.500  9.50  16.00  46.0
# VC      42.0  10.607143   5.961805  3.0  7.125  9.75  13.25  39.0
# WA     589.0   8.041030   7.622883  0.0  3.500  6.50   9.50  57.0

# %%
for i in np.unique(soils_char_essential['depth_interval']):
    subset = soils_char_essential[soils_char_essential['depth_interval'] == i]
    interval = subset.depth_interval[subset.index[0]].split('_')
    interval_upper_lower = interval[1:]
    lo = '-'.join(interval_upper_lower) + ' cm'
    n_sites = len(np.unique(subset['soil.char.site_location_name']))
    n_rows = len(subset)
    subset.plot.scatter(x = 'clay_mid', y = 'slga_clay', title = f'{lo}, n sites = {n_sites}, samples = {n_rows}',
                        ylim = (0,100), xlim = (0,100), 
                        xlabel = "TERN Mean Clay Content (%)", ylabel = "SLGA Mean Clay Content (%)")
    slope, intercept, r, p, se = stats.linregress(x = subset['clay_mid'], y = subset['slga_clay'])
    plt.plot(subset['clay_mid'],intercept + slope*subset['clay_mid'], label='fitted line')
    one_to_one = [i for i in range(101)]
    plt.plot(one_to_one, one_to_one, linestyle = 'dashed')
    plt.annotate(f'$y = {slope:.3f}x + {intercept:.3f}$\n$R^2$ = {r:.3f}\n$p = {p:.5f}$', xy = (10, 80))
    plt.grid(True)

# %%
len(np.unique(soils_char_essential['soil.char.site_location_name']))
# Out:
# 587
