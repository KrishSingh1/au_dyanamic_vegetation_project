# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
soils = pd.read_csv('../DATASETS/AusPlots_Extracted_Data/extracted_soil_bulk_2-0-6.csv').copy()
soils.head(5)
# Out:
#    Unnamed: 0 soil.bulk.site_unique soil.bulk.site_location_name  \
# 0           1      NTTMGD0001-53521                   NTTMGD0001
# 1           2      NTTMGD0001-53521                   NTTMGD0001
# 2           3      NTTMGD0001-53521                   NTTMGD0001
# 3           4      QDACHC0003-53467                   QDACHC0003
# 4           5      QDACHC0003-53467                   QDACHC0003
#
#    soil.bulk.site_location_visit_id soil.bulk.sample_id  \
# 0                             53521                   0
# 1                             53521                   1
# 2                             53521                   2
# 3                             53467                   0
# 4                             53467                   1
#
#    soil.bulk.paper_bag_weight  soil.bulk.oven_dried_weight_in_bag  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# ...

# %%
subset = pd.read_csv('../DATASETS/Sites_Subset_20231010/ausplots_site_info/sites_subset.csv').copy()
subset.head(5)
# Out:
#    Unnamed: 0       site_unique site_location_name     established_date  \
# 0         189  WAAPIL0003-57601         WAAPIL0003  2015-08-30T11:01:10
# 1         226  NSABHC0023-57099         NSABHC0023  2014-04-21T00:00:00
# 2         300  TCATCH0006-58807         TCATCH0006  2020-02-06T15:29:07
# 3         331  WAAGAS0002-58421         WAAGAS0002  2016-08-08T15:32:20
# 4         364  NSAMDD0014-56963         NSAMDD0014  2014-06-04T00:00:00
#
#                                          description bioregion_name  \
# 0  Millstream Chichester National Park. 200m east...            PIL
# 1  Langawirra Station. 11.3km north of homestead....            BHC
# 2  Liawenee Moor. 5.4km north west of Miena, 7.5k...            TCH
# 3  South Side of track, 10.1km west of abandoned ...            GAS
# 4  Scotia Sanctuary. 8kms north of homestead 131 ...            MDD
#
#   landform_pattern landform_element  site_slope  site_aspect  ...  \
# ...

# %%
sites = np.unique(subset.site_location_name)

# %%
soils[soils['soil.bulk.site_location_name'] == sites[0]]
# Out:
#      Unnamed: 0 soil.bulk.site_unique soil.bulk.site_location_name  \
# 940         941      NSABHC0023-57099                   NSABHC0023
# 941         942      NSABHC0023-57099                   NSABHC0023
# 942         943      NSABHC0023-57099                   NSABHC0023
#
#      soil.bulk.site_location_visit_id soil.bulk.sample_id  \
# 940                             57099                   0
# 941                             57099                   1
# 942                             57099                   2
#
#      soil.bulk.paper_bag_weight  soil.bulk.oven_dried_weight_in_bag  \
# 940                         NaN                                 NaN
# 941                         NaN                                 NaN
# 942                         NaN                                 NaN
#
#      soil.bulk.ring_weight  soil.bulk.gravel_weight  soil.bulk.ring_volume  \
# 940                    NaN                      NaN                 209.35
# ...

# %%
soils[soils['soil.bulk.site_location_name'] == sites[1]]
# Out:
#      Unnamed: 0 soil.bulk.site_unique soil.bulk.site_location_name  \
# 822         823      NSAMDD0014-56963                   NSAMDD0014
# 823         824      NSAMDD0014-56963                   NSAMDD0014
# 824         825      NSAMDD0014-56963                   NSAMDD0014
#
#      soil.bulk.site_location_visit_id soil.bulk.sample_id  \
# 822                             56963                   0
# 823                             56963                   1
# 824                             56963                   2
#
#      soil.bulk.paper_bag_weight  soil.bulk.oven_dried_weight_in_bag  \
# 822                        4.28                              510.85
# 823                        4.32                              524.32
# 824                        4.33                              524.13
#
#      soil.bulk.ring_weight  soil.bulk.gravel_weight  soil.bulk.ring_volume  \
# 822                 151.60                      0.0                 209.35
# ...

# %%
soils[soils['soil.bulk.site_location_name'] == sites[2]]
# Out:
#       Unnamed: 0 soil.bulk.site_unique soil.bulk.site_location_name  \
# 1452        1453      NSANAN0002-58561                   NSANAN0002
# 1453        1454      NSANAN0002-58561                   NSANAN0002
# 1454        1455      NSANAN0002-58561                   NSANAN0002
#
#       soil.bulk.site_location_visit_id soil.bulk.sample_id  \
# 1452                             58561                   0
# 1453                             58561                   1
# 1454                             58561                   2
#
#       soil.bulk.paper_bag_weight  soil.bulk.oven_dried_weight_in_bag  \
# 1452                         NaN                                 NaN
# 1453                         NaN                                 NaN
# 1454                         NaN                                 NaN
#
#       soil.bulk.ring_weight  soil.bulk.gravel_weight  soil.bulk.ring_volume  \
# 1452                    NaN                      NaN                 209.35
# ...

# %%
soils[soils['soil.bulk.site_location_name'] == sites[3]]
# Out:
#       Unnamed: 0 soil.bulk.site_unique soil.bulk.site_location_name  \
# 1444        1445      NSANSS0001-58579                   NSANSS0001
# 1445        1446      NSANSS0001-58579                   NSANSS0001
# 1446        1447      NSANSS0001-58579                   NSANSS0001
#
#       soil.bulk.site_location_visit_id soil.bulk.sample_id  \
# 1444                             58579           0 - 10cm.
# 1445                             58579         10 - 20 cm.
# 1446                             58579          20 - 30cm.
#
#       soil.bulk.paper_bag_weight  soil.bulk.oven_dried_weight_in_bag  \
# 1444                         6.5                               359.9
# 1445                         6.6                               389.0
# 1446                         6.5                               370.5
#
#       soil.bulk.ring_weight  soil.bulk.gravel_weight  soil.bulk.ring_volume  \
# 1444                  150.8                      NaN                 209.35
# ...

# %%
soils[soils['soil.bulk.site_location_name'] == sites[4]]
# Out:
#       Unnamed: 0 soil.bulk.site_unique soil.bulk.site_location_name  \
# 369          370      NTAFIN0002-53622                   NTAFIN0002
# 370          371      NTAFIN0002-53622                   NTAFIN0002
# 371          372      NTAFIN0002-53622                   NTAFIN0002
# 1057        1058      NTAFIN0002-58018                   NTAFIN0002
# 1058        1059      NTAFIN0002-58018                   NTAFIN0002
# 1059        1060      NTAFIN0002-58018                   NTAFIN0002
#
#       soil.bulk.site_location_visit_id soil.bulk.sample_id  \
# 369                              53622         0.20 - 0.30
# 370                              53622         0.10 - 0.20
# 371                              53622         0.00 - 0.10
# 1057                             58018                   0
# 1058                             58018                   1
# 1059                             58018                   2
#
# ...

# %%
soils[soils['soil.bulk.site_location_name'] == sites[5]]
# Out:
#      Unnamed: 0 soil.bulk.site_unique soil.bulk.site_location_name  \
# 451         452      NTAGFU0021-53668                   NTAGFU0021
#
#      soil.bulk.site_location_visit_id soil.bulk.sample_id  \
# 451                             53668         0.00 - 0.10
#
#      soil.bulk.paper_bag_weight  soil.bulk.oven_dried_weight_in_bag  \
# 451                        4.64                              497.84
#
#      soil.bulk.ring_weight  soil.bulk.gravel_weight  soil.bulk.ring_volume  \
# 451                 151.62                    34.55                 209.35
#
#      soil.bulk.gravel_volume  soil.bulk.fine_earth_weight_in_bag  \
# 451                     14.0                              311.67
#
#      soil.bulk.fine_earth_weight  soil.bulk.fine_earth_volume  \
# 451                       307.03                       195.35
#
#      soil.bulk.fine_earth_bulk_density  soil.bulk.gravel_bulk_density
# 451                               1.57                       2.467857

# %%
soils[soils['soil.bulk.site_location_name'] == sites[6]]
# Out:
#       Unnamed: 0 soil.bulk.site_unique soil.bulk.site_location_name  \
# 1960        1961      QDAEIU0010-58883                   QDAEIU0010
# 1961        1962      QDAEIU0010-58883                   QDAEIU0010
# 1962        1963      QDAEIU0010-58883                   QDAEIU0010
#
#       soil.bulk.site_location_visit_id soil.bulk.sample_id  \
# 1960                             58883                   0
# 1961                             58883                   1
# 1962                             58883                   2
#
#       soil.bulk.paper_bag_weight  soil.bulk.oven_dried_weight_in_bag  \
# 1960                        11.6                               488.4
# 1961                        11.5                               502.3
# 1962                        11.8                               502.8
#
#       soil.bulk.ring_weight  soil.bulk.gravel_weight  soil.bulk.ring_volume  \
# 1960                  144.1                     35.1                 209.35
# ...

# %%
soils[soils['soil.bulk.site_location_name'] == sites[7]]
# Out:
#      Unnamed: 0 soil.bulk.site_unique soil.bulk.site_location_name  \
# 697         698      QDASSD0015-56924                   QDASSD0015
# 698         699      QDASSD0015-56924                   QDASSD0015
# 699         700      QDASSD0015-56924                   QDASSD0015
#
#      soil.bulk.site_location_visit_id soil.bulk.sample_id  \
# 697                             56924                   0
# 698                             56924                   1
# 699                             56924                   2
#
#      soil.bulk.paper_bag_weight  soil.bulk.oven_dried_weight_in_bag  \
# 697                        4.93                              514.62
# 698                        4.99                              509.35
# 699                        4.91                              529.23
#
#      soil.bulk.ring_weight  soil.bulk.gravel_weight  soil.bulk.ring_volume  \
# 697                 152.06                      0.0                 209.35
# ...

# %%
soils_char = pd.read_csv('../DATASETS/AusPlots_Extracted_Data/extracted_soil_char_2-0-6.csv').copy()
soils_char.head(5)
# Out:
#    Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 0           1      NSABHC0013-53608                   NSABHC0013
# 1           2      WAAPIL0030-58057                   WAAPIL0030
# 2           3      WAAPIL0030-58057                   WAAPIL0030
# 3           4      WAAPIL0030-58057                   WAAPIL0030
# 4           5      NSABHC0013-53608                   NSABHC0013
#
#    soil.char.site_location_visit_id  soil.char.upper_depth  \
# 0                             53608                   0.50
# 1                             58057                   0.00
# 2                             58057                   0.09
# 3                             58057                   0.45
# 4                             53608                   0.30
#
#    soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 0                   0.60                NC                      NC
# 1                   0.09                A1                      MC
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[0]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 230          231      NSABHC0023-57099                   NSABHC0023
# 706          707      NSABHC0023-57099                   NSABHC0023
# 845          846      NSABHC0023-57099                   NSABHC0023
# 987          988      NSABHC0023-57099                   NSABHC0023
# 1259        1260      NSABHC0023-57099                   NSABHC0023
# 1409        1410      NSABHC0023-57099                   NSABHC0023
# 2139        2140      NSABHC0023-57099                   NSABHC0023
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 230                              57099                    0.1
# 706                              57099                    0.4
# 845                              57099                    0.6
# 987                              57099                    0.3
# 1259                             57099                    0.5
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[1]]
# Out:
#      Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 527         528      NSAMDD0014-56963                   NSAMDD0014
# 737         738      NSAMDD0014-56963                   NSAMDD0014
#
#      soil.char.site_location_visit_id  soil.char.upper_depth  \
# 527                             56963                   0.75
# 737                             56963                   0.00
#
#      soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 527                   1.00               A12                       S
# 737                   0.75               A11                       S
#
#     soil.char.texture_qualifier soil.char.texture_modifier  ... soil.char.ph  \
# 527                         NaN                        NaN  ...          9.1
# 737                         NaN                        NaN  ...          8.5
#
#     soil.char.pedality_grade soil.char.pedality_fabric  \
# 527                        G                         G
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[2]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 2351        2352      NSANAN0002-58561                   NSANAN0002
# 2354        2355      NSANAN0002-58561                   NSANAN0002
# 2355        2356      NSANAN0002-58561                   NSANAN0002
# 2356        2357      NSANAN0002-58561                   NSANAN0002
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 2351                             58561                   0.45
# 2354                             58561                   0.00
# 2355                             58561                   0.03
# 2356                             58561                   0.20
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 2351                   0.70                 B                      CS
# 2354                   0.03               Ash                      LS
# 2355                   0.20                 A                      CS
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[3]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 2213        2214      NSANSS0001-58579                   NSANSS0001
# 2214        2215      NSANSS0001-58579                   NSANSS0001
# 2318        2319      NSANSS0001-58579                   NSANSS0001
# 2319        2320      NSANSS0001-58579                   NSANSS0001
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 2213                             58579                    0.9
# 2214                             58579                    0.0
# 2318                             58579                    0.2
# 2319                             58579                    0.4
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 2213                    1.0                B3                      CL
# 2214                    0.2                 A                       L
# 2318                    0.4                A3                      ZL
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[4]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 395          396      NTAFIN0002-53622                   NTAFIN0002
# 823          824      NTAFIN0002-53622                   NTAFIN0002
# 1672        1673      NTAFIN0002-53622                   NTAFIN0002
# 1851        1852      NTAFIN0002-53622                   NTAFIN0002
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 395                              53622                   0.35
# 823                              53622                   0.45
# 1672                             53622                   0.05
# 1851                             53622                   0.00
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 395                    0.45                B1                      SL
# 823                    1.00                B2                     SCL
# 1672                   0.35                A3                      CS
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[5]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 484          485      NTAGFU0021-53668                   NTAGFU0021
# 1022        1023      NTAGFU0021-53668                   NTAGFU0021
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 484                              53668                    0.0
# 1022                             53668                    0.1
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 484                    0.10                A1                      LS
# 1022                   0.35                B2                     SCL
#
#      soil.char.texture_qualifier soil.char.texture_modifier  ... soil.char.ph  \
# 484                          NaN                          F  ...          6.2
# 1022                         NaN                        NaN  ...          6.8
#
#      soil.char.pedality_grade soil.char.pedality_fabric  \
# 484                         V                         E
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[6]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 2228        2229      QDAEIU0010-58883                   QDAEIU0010
# 2229        2230      QDAEIU0010-58883                   QDAEIU0010
# 2429        2430      QDAEIU0010-58883                   QDAEIU0010
# 3510        3511      QDAEIU0010-58883                   QDAEIU0010
# 3511        3512      QDAEIU0010-58883                   QDAEIU0010
# 3512        3513      QDAEIU0010-58883                   QDAEIU0010
# 3513        3514      QDAEIU0010-58883                   QDAEIU0010
# 3524        3525      QDAEIU0010-58883                   QDAEIU0010
# 3570        3571      QDAEIU0010-58883                   QDAEIU0010
# 3571        3572      QDAEIU0010-58883                   QDAEIU0010
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 2228                             58883                   0.80
# 2229                             58883                   1.10
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[7]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 414          415      QDASSD0015-56924                   QDASSD0015
# 1228        1229      QDASSD0015-56924                   QDASSD0015
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 414                              56924                    0.1
# 1228                             56924                    0.0
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 414                    0.65                B1                      SL
# 1228                   0.10                A1                       S
#
#      soil.char.texture_qualifier soil.char.texture_modifier  ... soil.char.ph  \
# 414                          NaN                        NaN  ...          6.5
# 1228                         NaN                        NaN  ...          5.7
#
#      soil.char.pedality_grade soil.char.pedality_fabric  \
# 414                         V                         E
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[8]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 1612        1613      SATSTP0005-53513                   SATSTP0005
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 1612                             53513                    0.0
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 1612                    1.0                A1                      NC
#
#      soil.char.texture_qualifier soil.char.texture_modifier  ... soil.char.ph  \
# 1612                          NC                         NC  ...         10.2
#
#      soil.char.pedality_grade soil.char.pedality_fabric  \
# 1612                       NC                        NC
#
#      soil.char.next_size_type_2 soil.char.next_size_type_1  \
# 1612                         NC                         NC
#
#      soil.char.smallest_size_type_2 soil.char.smallest_size_type_1  \
# 1612                             NC                             NC
#
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[9]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 3059        3060      TCATCH0006-58807                   TCATCH0006
# 3060        3061      TCATCH0006-58807                   TCATCH0006
# 3061        3062      TCATCH0006-58807                   TCATCH0006
# 3062        3063      TCATCH0006-58807                   TCATCH0006
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 3059                             58807                    0.0
# 3060                             58807                    0.1
# 3061                             58807                    0.2
# 3062                             58807                    0.3
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 3059                    0.1                A1                     SCL
# 3060                    0.2                A1                     SCL
# 3061                    0.3                B1                      CL
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[10]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 90            91      WAAGAS0002-58421                   WAAGAS0002
# 91            92      WAAGAS0002-58421                   WAAGAS0002
# 1964        1965      WAAGAS0002-58421                   WAAGAS0002
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 90                               58421                   0.01
# 91                               58421                   0.10
# 1964                             58421                   0.00
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 90                     0.10                A1                       L
# 91                     1.00                B2                     SCL
# 1964                   0.01                O2                       L
#
#      soil.char.texture_qualifier soil.char.texture_modifier  ... soil.char.ph  \
# ...

# %%
soils_char[soils_char['soil.char.site_location_name'] == sites[11]]
# Out:
#       Unnamed: 0 soil.char.site_unique soil.char.site_location_name  \
# 1727        1728      WAAPIL0003-57601                   WAAPIL0003
# 1736        1737      WAAPIL0003-57601                   WAAPIL0003
#
#       soil.char.site_location_visit_id  soil.char.upper_depth  \
# 1727                             57601                   0.00
# 1736                             57601                   0.05
#
#       soil.char.lower_depth soil.char.horizon soil.char.texture_grade  \
# 1727                   0.05                A1                      LS
# 1736                   0.25                A3                      CS
#
#      soil.char.texture_qualifier soil.char.texture_modifier  ... soil.char.ph  \
# 1727                          NC                         NC  ...          6.0
# 1736                          NC                         NC  ...          6.3
#
#      soil.char.pedality_grade soil.char.pedality_fabric  \
# 1727                        V                         E
# ...

# %%
soils_char_subset = soils_char[soils_char['soil.char.site_location_name'].isin(sites)].sort_values('soil.char.site_location_name')
soils_char_subset.drop(columns = 'Unnamed: 0', inplace = True)
soils_char_subset.reset_index(inplace = True, drop= True)

# %%
soils_char_subset
# Out:
#    soil.char.site_unique soil.char.site_location_name  \
# 0       NSABHC0023-57099                   NSABHC0023
# 1       NSABHC0023-57099                   NSABHC0023
# 2       NSABHC0023-57099                   NSABHC0023
# 3       NSABHC0023-57099                   NSABHC0023
# 4       NSABHC0023-57099                   NSABHC0023
# 5       NSABHC0023-57099                   NSABHC0023
# 6       NSABHC0023-57099                   NSABHC0023
# 7       NSAMDD0014-56963                   NSAMDD0014
# 8       NSAMDD0014-56963                   NSAMDD0014
# 9       NSANAN0002-58561                   NSANAN0002
# 10      NSANAN0002-58561                   NSANAN0002
# 11      NSANAN0002-58561                   NSANAN0002
# 12      NSANAN0002-58561                   NSANAN0002
# 13      NSANSS0001-58579                   NSANSS0001
# 14      NSANSS0001-58579                   NSANSS0001
# 15      NSANSS0001-58579                   NSANSS0001
# ...

# %%
soils_bulk = pd.read_csv('../DATASETS/AusPlots_Extracted_Data/extracted_soil_bulk_2-0-6.csv').copy()
soils_bulk.head(5)
# Out:
#    Unnamed: 0 soil.bulk.site_unique soil.bulk.site_location_name  \
# 0           1      NTTMGD0001-53521                   NTTMGD0001
# 1           2      NTTMGD0001-53521                   NTTMGD0001
# 2           3      NTTMGD0001-53521                   NTTMGD0001
# 3           4      QDACHC0003-53467                   QDACHC0003
# 4           5      QDACHC0003-53467                   QDACHC0003
#
#    soil.bulk.site_location_visit_id soil.bulk.sample_id  \
# 0                             53521                   0
# 1                             53521                   1
# 2                             53521                   2
# 3                             53467                   0
# 4                             53467                   1
#
#    soil.bulk.paper_bag_weight  soil.bulk.oven_dried_weight_in_bag  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# ...

# %%
soils_bulk_subset = soils_bulk[soils_bulk['soil.bulk.site_location_name'].isin(sites)].sort_values('soil.bulk.site_location_name')
soils_bulk_subset.drop(columns = 'Unnamed: 0', inplace = True)
soils_bulk_subset.reset_index(inplace = True, drop= True)

# %%
soils_bulk_subset
# Out:
#    soil.bulk.site_unique soil.bulk.site_location_name  \
# 0       NSABHC0023-57099                   NSABHC0023
# 1       NSABHC0023-57099                   NSABHC0023
# 2       NSABHC0023-57099                   NSABHC0023
# 3       NSAMDD0014-56963                   NSAMDD0014
# 4       NSAMDD0014-56963                   NSAMDD0014
# 5       NSAMDD0014-56963                   NSAMDD0014
# 6       NSANAN0002-58561                   NSANAN0002
# 7       NSANAN0002-58561                   NSANAN0002
# 8       NSANAN0002-58561                   NSANAN0002
# 9       NSANSS0001-58579                   NSANSS0001
# 10      NSANSS0001-58579                   NSANSS0001
# 11      NSANSS0001-58579                   NSANSS0001
# 12      NTAFIN0002-53622                   NTAFIN0002
# 13      NTAFIN0002-53622                   NTAFIN0002
# 14      NTAFIN0002-53622                   NTAFIN0002
# 15      NTAFIN0002-58018                   NTAFIN0002
# ...

# %%
soils_sub = pd.read_csv('../DATASETS/AusPlots_Extracted_Data/extracted_soil_subsites_2-0-6.csv').copy()
soils_sub.head(5)
# Out:
#    Unnamed: 0 soil.subsites.site_unique soil.subsites.site_location_name  \
# 0           1          NTTMGD0001-53521                       NTTMGD0001
# 1           2          NTTMGD0001-53521                       NTTMGD0001
# 2           3          NTTMGD0001-53521                       NTTMGD0001
# 3           4          NTTMGD0001-53521                       NTTMGD0001
# 4           5          NTTMGD0001-53521                       NTTMGD0001
#
#    soil.subsites.site_location_visit_id  soil.subsites.subsite_id  \
# 0                                 53521                         2
# 1                                 53521                         3
# 2                                 53521                         4
# 3                                 53521                         5
# 4                                 53521                         6
#
#    soil.subsites.zone  soil.subsites.easting  soil.subsites.northing  \
# ...

# %%
soils_sub_subset = soils_sub[soils_sub['soil.subsites.site_location_name'].isin(sites)].sort_values('soil.subsites.site_location_name')
soils_sub_subset.drop(columns = 'Unnamed: 0', inplace = True)
soils_sub_subset.reset_index(inplace = True, drop= True)

# %%
soils_sub_subset
# Out:
#     soil.subsites.site_unique soil.subsites.site_location_name  \
# 0            NSABHC0023-57099                       NSABHC0023
# 1            NSABHC0023-57099                       NSABHC0023
# 2            NSABHC0023-57099                       NSABHC0023
# 3            NSABHC0023-57099                       NSABHC0023
# 4            NSABHC0023-57099                       NSABHC0023
# ..                        ...                              ...
# 130          WAAPIL0003-57601                       WAAPIL0003
# 131          WAAPIL0003-57601                       WAAPIL0003
# 132          WAAPIL0003-57601                       WAAPIL0003
# 133          WAAPIL0003-57601                       WAAPIL0003
# 134          WAAPIL0003-57601                       WAAPIL0003
#
#      soil.subsites.site_location_visit_id  soil.subsites.subsite_id  \
# 0                                   57099                         1
# 1                                   57099                         6
# ...

# %%
info = pd.read_csv('../DATASETS/AusPlots_Extracted_Data/extracted_site_info_2-0-6.csv').copy()
info.head(5)
# Out:
#    Unnamed: 0 site.info.site_unique site.info.site_location_name  \
# 0           1      NSABBS0001-58580                   NSABBS0001
# 1           2      NSABBS0002-58555                   NSABBS0002
# 2           3      NSABBS0003-58581                   NSABBS0003
# 3           4      NSABBS0004-58556                   NSABBS0004
# 4           5      NSABBS0005-58582                   NSABBS0005
#
#   site.info.established_date  \
# 0        2018-05-11T10:11:00
# 1        2018-05-12T13:41:09
# 2        2018-05-13T11:11:00
# 3        2018-05-14T11:40:15
# 4        2018-05-15T12:06:00
#
#                                site.info.description site.info.bioregion_name  \
# 0  Warrumbungle National Park, 28.8km west of Coo...                      BBS
# 1  Warrumbungle National Park. 893m north west of...                      BBS
# 2  Pilliga State Conservation Area. 56.8km north ...                      BBS
# ...

# %%
info_subset = info[info['site.info.site_location_name'].isin(sites)].sort_values('site.info.site_location_name')
info_subset.drop(columns = 'Unnamed: 0', inplace = True)
info_subset.reset_index(inplace = True, drop= True)

# %%
info_subset
# Out:
#    site.info.site_unique site.info.site_location_name  \
# 0       NSABHC0023-57099                   NSABHC0023
# 1       NSAMDD0014-56963                   NSAMDD0014
# 2       NSANAN0002-58561                   NSANAN0002
# 3       NSANSS0001-58579                   NSANSS0001
# 4       NTAFIN0002-53622                   NTAFIN0002
# 5       NTAFIN0002-58018                   NTAFIN0002
# 6       NTAFIN0002-58787                   NTAFIN0002
# 7       NTAGFU0021-53668                   NTAGFU0021
# 8       QDAEIU0010-58883                   QDAEIU0010
# 9       QDASSD0015-56924                   QDASSD0015
# 10      QDASSD0015-57635                   QDASSD0015
# 11      QDASSD0015-58694                   QDASSD0015
# 12      SATSTP0005-53513                   SATSTP0005
# 13      SATSTP0005-58639                   SATSTP0005
# 14      TCATCH0006-58807                   TCATCH0006
# 15      WAAGAS0002-58421                   WAAGAS0002
# ...
