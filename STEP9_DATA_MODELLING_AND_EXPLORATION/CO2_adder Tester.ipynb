# %% [markdown]
# # Adding CO2
#
# This is to test how to incorporate CO2 into the dataset.

# %%
import numpy as np
import pandas as pd

# %%
CO2_data = pd.read_csv('../DATASETS/CO2_Dataset/global_co2_ann_1700_2022.txt', sep = "  ", header = None).copy()
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_22332\3891545369.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   CO2_data = pd.read_csv('../DATASETS/CO2_Dataset/global_co2_ann_1700_2022.txt', sep = "  ", header = None).copy()

# %%
CO2_data.rename(columns = {0: 'Year', 1: 'CO2'}, inplace = True)

# %%
CO2_data.columns
# Out:
# Index(['Year', 'CO2'], dtype='object')

# %%
CO2_data.plot(x = 'Year', y = 'CO2')
# Out:
# <Axes: xlabel='Year'>
